# %%
# Imports you may need
import seaborn as sns
from IPython.display import display, HTML
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import yfinance as yf
import json
import bz2
from dataloader import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# Cellule pour importer les questions qu'on aura fait individuellement, et sera supprimée à la fin.

from section1 import *
from finance import *

# %%
quotes = load_quotes(r"data/quotes-2020.json.bz2", limit = 1000, columns = ["quoteID", "speaker","date"])

# %%
quotes
# Out:
#                quoteID              speaker                 date
# 0    2020-01-28-000082                 None  2020-01-28 08:04:05
# 1    2020-01-16-000088           Sue Myrick  2020-01-16 12:00:13
# 2    2020-02-10-000142                 None  2020-02-10 23:45:54
# 3    2020-02-15-000053                 None  2020-02-15 14:12:51
# 4    2020-01-24-000168  Meghan King Edmonds  2020-01-24 20:37:09
# ..                 ...                  ...                  ...
# 995  2020-01-12-021411         Dabo Swinney  2020-01-12 12:00:00
# 996  2020-01-21-042452         Craig Arnold  2020-01-21 16:54:50
# 997  2020-02-21-033839        Seamus Hughes  2020-02-21 11:00:00
# 998  2020-02-21-033859   William Brent Bell  2020-02-21 07:37:55
# 999  2020-02-12-049718         Bruno Stagno  2020-02-12 12:05:00
#
# [1000 rows x 3 columns]

# %% [markdown]
# # Section 1 : blabla
# This is an example

# %%
section1a(quotes)

# %%
apple = yf.Ticker("AAPL").history(start='2019-01-01', end='2019-12-31')
apple.reset_index(inplace=True)

# %%
import matplotlib

matplotlib.rc_file_defaults()
ax1 = sns.set_style(style=None, rc=None )

fig, ax1 = plt.subplots(figsize=(12,6))
sns.barplot(
    data=apple,    
    x = 'Date', 
    y = 'Volume',
    ax = ax1)


ax2=ax1.twinx()

sns.pointplot(
    data=apple,
    x = 'Date',
    y = 'Open',
    marker = 'x',
    ax = ax2)

x_dates = apple['Date'].dt.strftime('%Y-%m').sort_values().unique()
ax1.xaxis.set_major_locator(matplotlib.dates.AutoDateLocator())
ax1.xaxis.set_major_formatter(matplotlib.dates.DateFormatter('%Y-%m'))
ax1.set_xticklabels(labels = x_dates, rotation=45, ha='right')
# Out:
# /var/folders/b7/04qkxmd52_ddr4d7bzj2t92w0000gn/T/ipykernel_31437/1709162801.py:26: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels = x_dates, rotation=45, ha='right')
# [Text(0.0, 0, '2018-12'),
#  Text(31.0, 0, '2019-01'),
#  Text(59.0, 0, '2019-02'),
#  Text(90.0, 0, '2019-03'),
#  Text(120.0, 0, '2019-04'),
#  Text(151.0, 0, '2019-05'),
#  Text(181.0, 0, '2019-06'),
#  Text(212.0, 0, '2019-07'),
#  Text(243.0, 0, '2019-08')]
