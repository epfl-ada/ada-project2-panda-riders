# %%
# Imports you may need
import seaborn as sns
from IPython.display import display, HTML
import matplotlib
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import yfinance as yf
import json
import bz2
from dataloader import *
from finance import *
# %load_ext autoreload
# %autoreload 2

# %%
# Cellule pour importer les questions qu'on aura fait individuellement, et sera supprimée à la fin.

from section1 import *
from finance import applestock

# %%
quotes = load_quotes(r"data/quotes-2008.json.bz2", limit = 1000, columns = ["quoteID", "speaker","date"])

# %%
quotes

# %% [markdown]
# # Stock
# This is an example

# %%
applestock()
# Out:
# We first load the dataset
#           Date       Open       High        Low      Close     Volume  \
# 0   2018-12-31  38.474331  38.675768  37.976807  38.282604  140014000
# 1   2019-01-02  37.590930  38.552002  37.430751  38.326294  148158800
# 2   2019-01-03  34.943130  35.365420  34.462596  34.508709  365248800
# 3   2019-01-04  35.076620  36.052252  34.899454  35.981869  234428400
# 4   2019-01-07  36.088651  36.120203  35.409106  35.901775  219111200
# ..         ...        ...        ...        ...        ...        ...
# 247 2019-12-23  69.106005  70.022393  69.066589  69.960808   98572000
# 248 2019-12-24  70.130772  70.180043  69.694751  70.027306   48478800
# 249 2019-12-26  70.162790  71.433910  70.133231  71.416664   93121200
# 250 2019-12-27  71.714752  72.416824  70.975729  71.389580  146266000
# 251 2019-12-30  71.305809  72.101493  70.261326  71.813271  144114400
#
#      Dividends  Stock Splits
# 0          0.0             0
# 1          0.0             0
# 2          0.0             0
# 3          0.0             0
# 4          0.0             0
# ..         ...           ...
# 247        0.0             0
# 248        0.0             0
# 249        0.0             0
# 250        0.0             0
# 251        0.0             0
#
# [252 rows x 8 columns]
# We observe the stock price and volume during the year
# /Users/raphaelattias/Documents/GitHub/ada-project2-panda-riders/finance.py:24: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax1.set_xticklabels(labels = x_dates, rotation=45, ha='right')
# We can also observe the distribution of the volume and daily price difference between     Open and Closing of the market.
